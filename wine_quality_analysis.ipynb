# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeDeecode/Red-wine-quality-report/blob/master/wine_quality_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

print("Setup complete")
# Out:
# Setup complete

# %%
wines = pd.read_csv("/content/wine data .csv")
print("Success")
# Out:
# Success

# %%
wines.shape
# Out:
# (1599, 12)

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
wines.describe(include = 'all')
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
bins = [0, 6.9, 10]
labels = ['bad', 'good']
wines['quality'] = pd.cut(wines['quality'], bins = bins,labels = labels )

# %% [markdown]
# ##Fixed Acidity

# %%
wines['quality'].value_counts()
# Out:
# bad     1382
# good     217
# Name: quality, dtype: int64

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['fixed acidity'], ax = ax[0])
ax[0].set_xlabel("Fixed acidity")
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF FIXED ACIDITY")

sns.boxenplot('fixed acidity', 'quality', data = wines, ax = ax[1])
ax[1].set_xlabel("Fixed acidity")
ax[1].set_ylabel("Quality")
ax[1].set_title("FIXED ACIDITY AND QUALITY RELATIONSHIP")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.show()

# %% [markdown]
# ##Volatile acidity

# %%
fig1, ax1 = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['volatile acidity'], color = 'purple', ax = ax1[0])
ax1[0].set_ylabel('Distribution')
ax1[0].set_title("DISTRIBUTION OF VOLATILE ACIDITY")


sns.boxenplot('volatile acidity', 'quality', data = wines, ax = ax1[1])
ax1[1].set_title("RELATIONSHIP BETWEEN VOLATILE ACIDITY AND QUALITY")
ax1[1].yaxis.set_label_position('right')
ax1[1].yaxis.tick_right

plt.show()

# %% [markdown]
# ##Citric acid

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))
sns.distplot(wines['citric acid'], color = 'red', ax = ax[0])
ax[0].set_ylabel("Count")
ax[0].set_title("DISTRIBUTION OF CITRIC ACID")


sns.boxplot('citric acid', 'quality', data = wines, ax = ax[1])
ax[1].set_title("CITRIC ACID AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_label_position('right')

plt.show()

# %% [markdown]
# ##Residual sugar

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['residual sugar'], color = 'orange', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF RESIDUAL SUGAR")

sns.violinplot('residual sugar', 'quality', data = wines, ax = ax[1])
ax[1].set_title("RESIDUAL SUGAR AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Chlorides

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['chlorides'], color = 'black', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF CHLORIDES")

sns.boxenplot('chlorides', 'quality', data = wines, ax = ax[1])
ax[1].set_title("CHLORIDES AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Free Sulphur dioxide

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['free sulfur dioxide'], color = 'green', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF FREE SULPHUR DIOXIDE")

sns.boxplot('free sulfur dioxide', 'quality', data = wines, ax = ax[1])
ax[1].set_title("FREE SULPHUR DIOXIDE AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Total sulphur dioxide

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['total sulfur dioxide'], color = 'yellow', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF TOTAL SULPHUR DIOXIDE")

sns.boxplot('total sulfur dioxide', 'quality', data = wines, ax = ax[1])
ax[1].set_title("TOTAL SULPHUR DIOXIDE AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Density

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['density'], color = 'indigo', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION AND DENSITY")

sns.violinplot('density', 'quality', data = wines, ax = ax[1])
ax[1].set_title("DENSITY AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##pH

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['pH'], color = 'green', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF pH")

sns.boxplot('pH', 'quality', data = wines, ax = ax[1])
ax[1].set_title("pH AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Sulphates

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['sulphates'], color = 'brown', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF SULPHATES")

sns.violinplot('sulphates', 'quality', data = wines, ax = ax[1])
ax[1].set_title("SULPHATES AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# ##Alcohol

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 6))

sns.distplot(wines['alcohol'], color = 'gold', ax = ax[0])
ax[0].set_ylabel("Distribution")
ax[0].set_title("DISTRIBUTION OF ALCOHOL")

sns.boxplot('alcohol', 'quality', data = wines, ax = ax[1])
ax[1].set_title("ALCOHOL AND QUALITY")
ax[1].yaxis.tick_right()
ax[1].yaxis.set_ticks_position('right')

plt.show()

# %% [markdown]
# #**THANK YOU FOR VIEWING MY PROJECT!!!**
